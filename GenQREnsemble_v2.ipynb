# %%
# !pip install python-terrier
# !pip install transformers

import torch
import pyterrier as pt
import requests
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, T5Tokenizer
from pathlib import Path
# Out:
# Requirement already satisfied: python-terrier in c:\users\basma\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (1.26.4)
# Requirement already satisfied: pandas in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (2.2.2)
# Requirement already satisfied: more-itertools in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (10.1.0)
# Requirement already satisfied: tqdm in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (4.66.4)
# Requirement already satisfied: requests in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (2.32.2)
# Requirement already satisfied: ir-datasets>=0.3.2 in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (0.5.9)
# Requirement already satisfied: wget in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (3.2)
# Requirement already satisfied: pyjnius>=1.4.2 in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: deprecated in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (1.2.15)
# Requirement already satisfied: scipy in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (1.13.1)
# Requirement already satisfied: ir-measures>=0.3.1 in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (0.3.6)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: jinja2 in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (3.1.4)
# Requirement already satisfied: statsmodels in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (0.14.2)
# Requirement already satisfied: dill in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (0.3.8)
# Requirement already satisfied: joblib in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (1.4.2)
# Requirement already satisfied: chest in c:\users\basma\anaconda3\lib\site-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (2.5.3)
# Requirement already satisfied: lxml>=4.5.2 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (5.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in c:\users\basma\anaconda3\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basma\anaconda3\lib\site-packages (from requests->python-terrier) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basma\anaconda3\lib\site-packages (from requests->python-terrier) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basma\anaconda3\lib\site-packages (from requests->python-terrier) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basma\anaconda3\lib\site-packages (from requests->python-terrier) (2024.12.14)
# Requirement already satisfied: colorama in c:\users\basma\anaconda3\lib\site-packages (from tqdm->python-terrier) (0.4.6)
# Requirement already satisfied: heapdict in c:\users\basma\anaconda3\lib\site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\basma\anaconda3\lib\site-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\basma\anaconda3\lib\site-packages (from jinja2->python-terrier) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\basma\anaconda3\lib\site-packages (from pandas->python-terrier) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\basma\anaconda3\lib\site-packages (from pandas->python-terrier) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\basma\anaconda3\lib\site-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\basma\anaconda3\lib\site-packages (from statsmodels->python-terrier) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\basma\anaconda3\lib\site-packages (from statsmodels->python-terrier) (23.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\basma\anaconda3\lib\site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: six in c:\users\basma\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in c:\users\basma\anaconda3\lib\site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)
# Requirement already satisfied: transformers in c:\users\basma\anaconda3\lib\site-packages (4.37.2)
# Requirement already satisfied: filelock in c:\users\basma\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\basma\anaconda3\lib\site-packages (from transformers) (2.32.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\basma\anaconda3\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\basma\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\basma\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\basma\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basma\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basma\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basma\anaconda3\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basma\anaconda3\lib\site-packages (from requests->transformers) (2024.12.14)

# %%
pt.init()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pt.init()
#
# File ~\anaconda3\Lib\site-packages\pyterrier\java\_utils.py:63, in before_init.<locals>._wrapper(*args, **kwargs)
#      60 @wraps(fn)
#      61 def _wrapper(*args, **kwargs):
#      62     if started():
# ---> 63         raise RuntimeError(f'You can only call {fn} before either you start using java or call pt.java.init()')
#      64     return fn(*args, **kwargs)
#
# RuntimeError: You can only call <function legacy_init at 0x0000026E302E6980> before either you start using java or call pt.java.init()

# %%
from pathlib import Path

# Load BM25 Index using PyTerrier
DATASET_NAME = "irds:beir/webis-touche2020"

# Load Dataset
dataset = pt.datasets.get_dataset(DATASET_NAME)
queries = dataset.get_topics()
qrels = dataset.get_qrels()
# Out:
# There are multiple query fields available: ('text', 'description', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.

# %%
# index = pt.index.IterDictIndexer(
#     str(Path.cwd()),
#     meta={
#         "docno": 39,
#         "text": 131072,
#     },
#     type=pt.index.IndexingType.MEMORY,
# ).index(dataset.get_corpus_iter())

index = pt.IndexFactory.of(str(Path.cwd() / "indices" / "webis_index"))
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
# Out:
# C:\Users\basma\AppData\Local\Temp\ipykernel_30112\189753431.py:11: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(index, wmodel="BM25")

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-large")
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-large")
# Out:
# C:\Users\basma\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import re

storage = {}

def generate_expansion_terms(query, instructions):
    expansion_terms_list = []
    for instruction in instructions:

        if query + str(instruction) in storage:
            expansion_terms = storage[query + str(instruction)]
            expansion_terms_list += expansion_terms
        else:
            prompt = f"{instruction}. Provide a comma-separated list of only expansion terms (single words) relevant to the query: {query}"
            inputs = tokenizer(prompt, return_tensors="pt")
            outputs = model.generate(**inputs,
                                     do_sample=True,
                                     top_p=0.92,
                                     top_k=200,
                                     repetition_penalty=1.2,
                                     temperature=1.0,
                                     max_new_tokens=50  # Reduce token limit to prevent full sentences
                                     )
            generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

            # Post-process output: split by commas, strip spaces, remove problematic characters
            expansion_terms = [term.strip().replace("?", "").replace('"', '').replace("'", "")
                               for term in generated_text.split(",") if term.strip()]
            storage[query + str(instruction)] = expansion_terms
            expansion_terms_list += expansion_terms

    print(re.sub(r"[^a-zA-Z\s]", "", query + " " + " ".join(expansion_terms_list)))
    return re.sub(r"[^a-zA-Z\s]", "", query + " " + " ".join(expansion_terms_list))

# %%
# Step 2: Retrieve Documents with BM25
def retrieve_documents(query, k=10):
    """Retrieve top-K documents using BM25 in PyTerrier."""
    results = bm25.search(query, k)
    return results[["docno", "score"]].values.tolist()

# %%
import itertools
import pandas as pd

def evaluate_combinations(paraphrases, k=10):
    """Evaluate retrieval performance for all combinations of paraphrases."""

    results_list = []

    # Generate all subsets of paraphrases
    all_paraphrase_subsets = [subset for L in range(1, len(paraphrases) + 1) for subset in itertools.combinations(paraphrases, L)]

    i = 0
    for subset in all_paraphrase_subsets:
        subset_name = " | ".join(subset)  # For display
        print(f"\n🔹 Evaluating Combination: {subset_name}")
        print(f"\n Subset number {i}")
        i += 1

        # for _, row in queries.iterrows():
        for query in ["Is golf a sport?"]:
            # query = row["text"]
            # qid = row["qid"]
            qid = 1

            # Generate reformulated queries using the current subset of paraphrases
            reformed_query = generate_expansion_terms(query, subset)

            results = (retrieve_documents(reformed_query, k))

            # Aggregate scores
            aggregated_results = {}
            for docid, score in results:
                aggregated_results[docid] = aggregated_results.get(docid, 0) + score

            sorted_results = sorted(aggregated_results.items(), key=lambda x: x[1], reverse=True)[:k]

            # Store results for evaluation
            for rank, (docid, score) in enumerate(sorted_results):
                results_list.append({"qid": qid, "docno": docid, "rank": rank + 1, "score": score, "subset": subset_name})

    # Convert results to DataFrame
    results_df = pd.DataFrame(results_list)

    # Compute evaluation metrics for each subset
    print("\n📊 Evaluation Results Per Combination:")
    for subset in all_paraphrase_subsets:
        subset_name = " | ".join(subset)
        subset_df = results_df.loc[results_df["subset"] == subset_name].copy()
        eval_metrics = pt.Evaluate(subset_df, qrels, metrics=["map", "recip_rank", "ndcg_cut_10"])
        print(f"\n🔹 Results for '{subset_name}': {eval_metrics}")

# %%
# Manually input your paraphrased instructions here
paraphrases = [
    "Improve the search effectiveness by suggesting expansion terms for the query",
    "Recommend expansion terms for the query to improve search results",
    "Improve the search effectiveness by suggesting useful expansion terms for the query",
    "Maximize search utility by suggesting relevant expansion phrases for the query",
    "Enhance search efficiency by proposing valuable terms to expand the query",
    "Elevate search performance by recommending relevant expansion phrases for the query",
    "Boost the search accuracy by providing helpful expansion terms to enrich the query",
    "Increase the search efficacy by offering beneficial expansion keywords for the query",
    "Optimize search results by suggesting meaningful expansion terms to enhance the query",
    "Enhance search outcomes by recommending beneficial expansion terms to supplement the query"
]

# %%
evaluate_combinations(paraphrases)
# Out:
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query
#
#  Subset number 0
# Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results
#
#  Subset number 1
# Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query
#
#  Subset number 2
# Is golf a sport golf sport
#
# 🔹 Evaluating Combination: Maximize search utility by suggesting relevant expansion phrases for the query
#
#  Subset number 3
# Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Enhance search efficiency by proposing valuable terms to expand the query
#
#  Subset number 4
# Is golf a sport List of governing body for golf
#
# 🔹 Evaluating Combination: Elevate search performance by recommending relevant expansion phrases for the query
#
#  Subset number 5
# Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 6
# Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 7
# Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 8
# Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 9
# Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results
#
#  Subset number 10
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Improve the search effectiveness by suggesting useful expansion terms for the query
#
#  Subset number 11
# Is golf a sport Is golf a sport golf sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Maximize search utility by suggesting relevant expansion phrases for the query
#
#  Subset number 12
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Enhance search efficiency by proposing valuable terms to expand the query
#
#  Subset number 13
# Is golf a sport Is golf a sport List of governing body for golf
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Elevate search performance by recommending relevant expansion phrases for the query
#
#  Subset number 14
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 15
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 16
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 17
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 18
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Improve the search effectiveness by suggesting useful expansion terms for the query
#
#  Subset number 19
# Is golf a sport Golf is a sport golf sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Maximize search utility by suggesting relevant expansion phrases for the query
#
#  Subset number 20
# Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Enhance search efficiency by proposing valuable terms to expand the query
#
#  Subset number 21
# Is golf a sport Golf is a sport List of governing body for golf
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Elevate search performance by recommending relevant expansion phrases for the query
#
#  Subset number 22
# Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 23
# Is golf a sport Golf is a sport Golf is a sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 24
# Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 25
# Is golf a sport Golf is a sport Golf is a sport
#
# 🔹 Evaluating Combination: Recommend expansion terms for the query to improve search results | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 26
# Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query | Maximize search utility by suggesting relevant expansion phrases for the query
#
#  Subset number 27
# Is golf a sport golf sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query | Enhance search efficiency by proposing valuable terms to expand the query
#
#  Subset number 28
# Is golf a sport golf sport List of governing body for golf
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query | Elevate search performance by recommending relevant expansion phrases for the query
#
#  Subset number 29
# Is golf a sport golf sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query | Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 30
# Is golf a sport golf sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 31
# Is golf a sport golf sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 32
# Is golf a sport golf sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting useful expansion terms for the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 33
# Is golf a sport golf sport Is golf a sport
#
# 🔹 Evaluating Combination: Maximize search utility by suggesting relevant expansion phrases for the query | Enhance search efficiency by proposing valuable terms to expand the query
#
#  Subset number 34
# Is golf a sport Is golf a sport List of governing body for golf
#
# 🔹 Evaluating Combination: Maximize search utility by suggesting relevant expansion phrases for the query | Elevate search performance by recommending relevant expansion phrases for the query
#
#  Subset number 35
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Maximize search utility by suggesting relevant expansion phrases for the query | Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 36
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Maximize search utility by suggesting relevant expansion phrases for the query | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 37
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Maximize search utility by suggesting relevant expansion phrases for the query | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 38
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Maximize search utility by suggesting relevant expansion phrases for the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 39
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Enhance search efficiency by proposing valuable terms to expand the query | Elevate search performance by recommending relevant expansion phrases for the query
#
#  Subset number 40
# Is golf a sport List of governing body for golf Is golf a sport
#
# 🔹 Evaluating Combination: Enhance search efficiency by proposing valuable terms to expand the query | Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 41
# Is golf a sport List of governing body for golf Golf is a sport
#
# 🔹 Evaluating Combination: Enhance search efficiency by proposing valuable terms to expand the query | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 42
# Is golf a sport List of governing body for golf Is golf a sport
#
# 🔹 Evaluating Combination: Enhance search efficiency by proposing valuable terms to expand the query | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 43
# Is golf a sport List of governing body for golf Golf is a sport
#
# 🔹 Evaluating Combination: Enhance search efficiency by proposing valuable terms to expand the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 44
# Is golf a sport List of governing body for golf Is golf a sport
#
# 🔹 Evaluating Combination: Elevate search performance by recommending relevant expansion phrases for the query | Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 45
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Elevate search performance by recommending relevant expansion phrases for the query | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 46
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Elevate search performance by recommending relevant expansion phrases for the query | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 47
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Elevate search performance by recommending relevant expansion phrases for the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 48
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Boost the search accuracy by providing helpful expansion terms to enrich the query | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 49
# Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Boost the search accuracy by providing helpful expansion terms to enrich the query | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 50
# Is golf a sport Golf is a sport Golf is a sport
#
# 🔹 Evaluating Combination: Boost the search accuracy by providing helpful expansion terms to enrich the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 51
# Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Increase the search efficacy by offering beneficial expansion keywords for the query | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 52
# Is golf a sport Is golf a sport Golf is a sport
#
# 🔹 Evaluating Combination: Increase the search efficacy by offering beneficial expansion keywords for the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 53
# Is golf a sport Is golf a sport Is golf a sport
#
# 🔹 Evaluating Combination: Optimize search results by suggesting meaningful expansion terms to enhance the query | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 54
# Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Improve the search effectiveness by suggesting useful expansion terms for the query
#
#  Subset number 55
# Is golf a sport Is golf a sport Golf is a sport golf sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Maximize search utility by suggesting relevant expansion phrases for the query
#
#  Subset number 56
# Is golf a sport Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Enhance search efficiency by proposing valuable terms to expand the query
#
#  Subset number 57
# Is golf a sport Is golf a sport Golf is a sport List of governing body for golf
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Elevate search performance by recommending relevant expansion phrases for the query
#
#  Subset number 58
# Is golf a sport Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Boost the search accuracy by providing helpful expansion terms to enrich the query
#
#  Subset number 59
# Is golf a sport Is golf a sport Golf is a sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Increase the search efficacy by offering beneficial expansion keywords for the query
#
#  Subset number 60
# Is golf a sport Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Optimize search results by suggesting meaningful expansion terms to enhance the query
#
#  Subset number 61
# Is golf a sport Is golf a sport Golf is a sport Golf is a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Recommend expansion terms for the query to improve search results | Enhance search outcomes by recommending beneficial expansion terms to supplement the query
#
#  Subset number 62
# Is golf a sport Is golf a sport Golf is a sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Improve the search effectiveness by suggesting useful expansion terms for the query | Maximize search utility by suggesting relevant expansion phrases for the query
#
#  Subset number 63
# Is golf a sport Is golf a sport golf sport Is golf a sport
#
# 🔹 Evaluating Combination: Improve the search effectiveness by suggesting expansion terms for the query | Improve the search effectiveness by suggesting useful expansion terms for the query | Enhance search efficiency by proposing valuable terms to expand the query
#
#  Subset number